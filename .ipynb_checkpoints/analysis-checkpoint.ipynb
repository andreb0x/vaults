# %%
from locallib import *
print(w3.isConnected())
# Out:
# current block 30959146
# True

# %%
def load_data(protocol,asset_name):
    if protocol == "beefy":
        supply = np.load('data/%s_%s_supply.npy'%(protocol,asset_name),allow_pickle=True)
        bal = np.load('data/%s_%s_balance.npy'%(protocol,asset_name),allow_pickle=True)
        pps = np.load('data/%s_%s_pricepershare.npy'%(protocol,asset_name),allow_pickle=True)
        return {'supply':supply,"balance":bal,"pricepershare":pps}
    if protocol == "yearn":
        assets = np.load('data/%s_%s_assets.npy'%(protocol,asset_name),allow_pickle=True)
        debt = np.load('data/%s_%s_debt.npy'%(protocol,asset_name),allow_pickle=True)
        supply = np.load('data/%s_%s_supply.npy'%(protocol,asset_name),allow_pickle=True)
        pps = np.load('data/%s_%s_pricepershare.npy'%(protocol,asset_name),allow_pickle=True)
        return {'supply':supply,"assets":assets,"pricepershare":pps,"debt":debt}

# %% [markdown]
# # beefy

# %% [markdown]
# https://ftmscan.com/address/0x49c68eDb7aeBd968F197121453e41b8704AcdE0C#readContract

# %%
len(beefyVaults.keys()),beefyVaults.keys()
# Out:
# (21,
#  dict_keys(['bifi', 'btc1', 'btc2', 'eth1', 'eth2', 'ftm1', 'ftm2', 'usdc1', 'usdc2', 'usdt1', 'usdt2', 'mim1', 'mim2', 'dai1', 'dai2', 'boo1', 'frax1', 'crv1', 'crv2', 'spell1', 'dola1']))

# %% [markdown]
# ## TVL

# %%
f,axar = plt.subplots(7,3,figsize=(30,55)); axar=axar.reshape(-1)
for aidx,asset_name in enumerate(beefyVaults.keys()):
    ax = axar[aidx]
    supply,bal,pps = load_data('beefy',asset_name).values()
    ax.plot(bal,c='b',label='bal')
    ax.plot(supply,c='darkgreen',label='supply')
    ax.set_title(asset_name)

# %% [markdown]
# ## PPS

# %%
f,axar = plt.subplots(7,3,figsize=(30,55)); axar=axar.reshape(-1)
for aidx,asset_name in enumerate(beefyVaults.keys()):
    ax = axar[aidx]
    supply,bal,pps = load_data('beefy',asset_name).values()
    ax.plot(pps,c='k',label='pps')
    ax.set_title(asset_name)

# %% [markdown]
# # Yearn

# %% [markdown]
# # TVL

# %% [markdown]
# ## PPS

# %%
f,axar = plt.subplots(7,3,figsize=(30,55)); axar=axar.reshape(-1)
for aidx,asset_name in enumerate(beefyVaults.keys()):
    ax = axar[aidx]
    supply,bal,pps = load_data('beefy',asset_name).values()
    ax.plot(pps,c='k',label='pps')
    ax.set_title(asset_name)
